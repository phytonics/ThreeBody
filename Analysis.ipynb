# %%
import lightkurve as lk
from lightkurve.lightcurve import KeplerLightCurve as LightCurve
from kepler import *
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4874b3e51227> in <module>
# ----> 1 import lightkurve as lk
#       2 from lightkurve.lightcurve import KeplerLightCurve as LightCurve
#       3 from kepler import *
#       4
#
# ~\AppData\Roaming\Python\Python38\site-packages\lightkurve\__init__.py in <module>
#      35
#      36 from .version import __version__
# ---> 37 from . import units  # enable ppt and ppm as units
#      38 from .time import *
#      39 from .lightcurve import *
#
# ~\AppData\Roaming\Python\Python38\site-packages\lightkurve\units.py in <module>
#       1 """Define custom AstroPy units commonly used by the Kepler/TESS community."""
# ----> 2 from astropy import units as u
#       3
#       4 __all__ = ["ppt", "ppm"]
#       5
#
# ~\.conda\envs\ThreeBody\lib\site-packages\astropy\__init__.py in <module>
#      90
#      91 _check_requirement('numpy', __minimum_numpy_version__)
# ---> 92 _check_requirement('erfa', __minimum_erfa_version__)
#      93
#      94
#
# ~\.conda\envs\ThreeBody\lib\site-packages\astropy\__init__.py in _check_requirement(name, minimum_version)
#      84         msg = (f"{name} version {minimum_version} or later must "
#      85                f"be installed to use Astropy. {import_fail}")
# ---> 86         raise ImportError(msg)
#      87
#      88     return module
#
# ImportError: erfa version 1.7 or later must be installed to use Astropy. erfa is not installed.

# %%
keplerIds = getKplrIds()
k2Ids = getK2Ids()

# %%
## Functions ack
# Out:
# [757076,
#  757099,
#  757137,
#  757218,
#  757231,
#  757280,
#  757450,
#  891901,
#  891916,
#  892010,
#  892107,
#  892195,
#  892203,
#  892376,
#  892553,
#  892667,
#  892675,
#  892678,
#  892713,
#  892718,
#  892738,
#  892760,
#  892772,
#  892828,
#  892832,
#  892834,
#  892882,
#  892911,
#  892946,
#  892977,
#  892986,
#  893004,
#  893033,
#  893165,
#  893209,
#  893210,
#  893214,
#  893233,
#  893234,
#  893286,
#  893288,
#  893305,
#  893383,
#  893468,
#  893505,
#  893507,
#  893559,
#  893647,
#  893676,
#  893730,
#  893750,
#  893940,
#  893944,
#  893946,
#  1025494,
#  1025578,
#  1025623,
#  1025816,
#  1025859,
#  1025986,
#  1026032,
#  1026084,
#  1026089,
#  1026133,
#  1026146,
#  1026165,
#  1026173,
#  1026180,
#  1026255,
#  1026287,
#  1026294,
#  1026309,
#  1026321,
#  1026326,
#  1026328,
#  1026356,
#  1026400,
#  1026452,
#  1026473,
#  1026474,
#  1026475,
#  1026504,
#  1026647,
#  1026669,
#  1026838,
#  1026861,
#  1026895,
#  1026911,
#  1026957,
#  1026992,
#  1027016,
#  1027030,
#  1027110,
#  1027226,
#  1027252,
#  1027277,
#  1027330,
#  1027337,
#  1027338,
#  1027397,
#  1027438,
#  1027536,
#  1027582,
#  1027631,
#  1027696,
#  1027707,
#  1027710,
#  1027740,
#  1027842,
#  1027877,
#  1027900,
#  1027948,
#  1028012,
#  1028018,
#  1028085,
#  1028120,
#  1028201,
#  1028246,
#  1028267,
#  1028354,
#  1028424,
#  1028640,
#  1028843,
#  1160655,
#  1160660,
#  1160684,
#  1160789,
#  1160867,
#  1160887,
#  1160891,
#  1160919,
#  1160947,
#  1160986,
#  1161092,
#  1161137,
#  1161145,
#  1161315,
#  1161338,
#  1161345,
#  1161402,
#  1161432,
#  1161447,
#  1161491,
#  1161501,
#  1161537,
#  1161557,
#  1161618,
#  1161620,
#  1161699,
#  1161803,
#  1161869,
#  1161908,
#  1161949,
#  1161965,
#  1162036,
#  1162051,
#  1162150,
#  1162181,
#  1162220,
#  1162222,
#  1162339,
#  1162345,
#  1162466,
#  1162467,
#  1162617,
#  1162635,
#  1162715,
#  1162725,
#  1162746,
#  1162784,
#  1162850,
#  1162875,
#  1163078,
#  1163090,
#  1163114,
#  1163211,
#  1163235,
#  1163238,
#  1163244,
#  1163248,
#  1163286,
#  1163303,
#  1163333,
#  1163359,
#  1163449,
#  1163453,
#  1163576,
#  1163579,
#  1163588,
#  1163621,
#  1163623,
#  1163675,
#  1163712,
#  1163943,
#  1163991,
#  1163994,
#  1164071,
#  1164102,
#  1164109,
#  1164130,
#  1164207,
#  1164272,
#  1164274,
#  1164301,
#  1164333,
#  1164356,
#  1164363,
#  1164407,
#  1164418,
#  1164571,
#  1164583,
#  1164584,
#  1164590,
#  1292018,
#  1292087,
#  1292147,
#  1292384,
#  1292427,
#  1292493,
#  1292498,
#  1292666,
#  1292688,
#  1292763,
#  1292798,
#  1292834,
#  1292978,
#  1293031,
#  1293046,
#  1293177,
#  1293261,
#  1293357,
#  1293379,
#  1293393,
#  1293468,
#  1293521,
#  1293551,
#  1293563,
#  1293564,
#  1293587,
#  1293667,
#  1293671,
#  1293737,
#  1293743,
#  1293785,
#  1293814,
#  1293835,
#  1293861,
#  1293907,
#  1293928,
#  1293946,
#  1293993,
#  1294029,
#  1294088,
#  1294122,
#  1294214,
#  1294229,
#  1294308,
#  1294325,
#  1294382,
#  1294385,
#  1294419,
#  1294535,
#  1294567,
#  1294578,
#  1294648,
#  1294649,
#  1294670,
#  1294756,
#  1294869,
#  1294924,
#  1294953,
#  1294997,
#  1295017,
#  1295069,
#  1295162,
#  1295195,
#  1295276,
#  1295289,
#  1295296,
#  1295333,
#  1295375,
#  1295427,
#  1295448,
#  1295475,
#  1295504,
#  1295531,
#  1295546,
#  1295597,
#  1295693,
#  1295737,
#  1295776,
#  1295961,
#  1295980,
#  1296002,
#  1296063,
#  1296068,
#  1296110,
#  1296164,
#  1296179,
#  1296255,
#  1296262,
#  1296281,
#  1296334,
#  1296335,
#  1296415,
#  1296491,
#  1296507,
#  1296700,
#  1296721,
#  1296779,
#  1296787,
#  1296817,
#  1296862,
#  1296984,
#  1297058,
#  1297166,
#  1297263,
#  1297272,
#  1297303,
#  1297347,
#  1297463,
#  1297501,
#  1297510,
#  1429092,
#  1429120,
#  1429145,
#  1429153,
#  1429261,
#  1429275,
#  1429290,
#  1429337,
#  1429345,
#  1429367,
#  1429375,
#  1429385,
#  1429390,
#  1429426,
#  1429475,
#  1429486,
#  1429497,
#  1429505,
#  1429567,
#  1429575,
#  1429580,
#  1429589,
#  1429626,
#  1429629,
#  1429653,
#  1429729,
#  1429751,
#  1429795,
#  1429893,
#  1429921,
#  1429977,
#  1430118,
#  1430163,
#  1430171,
#  1430199,
#  1430207,
#  1430219,
#  1430227,
#  1430239,
#  1430305,
#  1430330,
#  1430333,
#  1430349,
#  1430350,
#  1430353,
#  1430444,
#  1430511,
#  1430590,
#  1430636,
#  1430666,
#  1430670,
#  1430741,
#  1430810,
#  1430865,
#  1430880,
#  1430893,
#  1430912,
#  1430977,
#  1430985,
#  1431059,
#  1431060,
#  1431075,
#  1431091,
#  1431114,
#  1431116,
#  1431122,
#  1431134,
#  1431181,
#  1431262,
#  1431287,
#  1431316,
#  1431344,
#  1431354,
#  1431379,
#  1431381,
#  1431474,
#  1431501,
#  1431502,
#  1431567,
#  1431599,
#  1431693,
#  1431705,
#  1431727,
#  1431791,
#  1431794,
#  1431845,
#  1431965,
#  1432022,
#  1432047,
#  1432060,
#  1432086,
#  1432091,
#  1432149,
#  1432184,
#  1432214,
#  1432231,
#  1432248,
#  1432278,
#  1432469,
#  1432520,
#  1432551,
#  1432587,
#  1432685,
#  1432700,
#  1432735,
#  1432745,
#  1432789,
#  1432825,
#  1432847,
#  1432865,
#  1432907,
#  1432934,
#  1432978,
#  1432979,
#  1433040,
#  1433067,
#  1433104,
#  1433132,
#  1433399,
#  1433410,
#  1433445,
#  1433477,
#  1433498,
#  1433510,
#  1433531,
#  1433534,
#  1433586,
#  1433593,
#  1433622,
#  1433628,
#  1433642,
#  1433714,
#  1433725,
#  1433730,
#  1433735,
#  1433755,
#  1433760,
#  1433803,
#  1433894,
#  1433899,
#  1433962,
#  1433972,
#  1433980,
#  1433989,
#  1434013,
#  1434116,
#  1434231,
#  1434259,
#  1434277,
#  1434286,
#  1434288,
#  1434326,
#  1434353,
#  1434372,
#  1434395,
#  1434397,
#  1434455,
#  1434522,
#  1434531,
#  1434583,
#  1434589,
#  1434591,
#  1434610,
#  1434660,
#  1434696,
#  1434708,
#  1434792,
#  1434800,
#  1434976,
#  1434988,
#  1435008,
#  1435038,
#  1435108,
#  1435143,
#  1435158,
#  1435229,
#  1435260,
#  1435272,
#  1435403,
#  1435448,
#  1435467,
#  1435573,
#  1435632,
#  1435717,
#  1435736,
#  1435818,
#  1435836,
#  1435930,
#  1435987,
#  1436132,
#  1436140,
#  1436265,
#  1569599,
#  1569682,
#  1569743,
#  1569746,
#  1569792,
#  1569822,
#  1569823,
#  1569842,
#  1569843,
#  1569849,
#  1569863,
#  1569897,
#  1569909,
#  1569924,
#  1569969,
#  1569974,
#  1569983,
#  1569985,
#  1569986,
#  1569999,
#  1570023,
#  1570026,
#  1570099,
#  1570150,
#  1570172,
#  1570191,
#  1570221,
#  1570253,
#  1570270,
#  1570275,
#  1570311,
#  1570349,
#  1570366,
#  1570400,
#  1570466,
#  1570529,
#  1570552,
#  1570554,
#  1570608,
#  1570617,
#  1570649,
#  1570703,
#  1570711,
#  1570713,
#  1570915,
#  1570918,
#  1570924,
#  1570929,
#  1570994,
#  1571003,
#  1571088,
#  1571152,
#  1571237,
#  1571298,
#  1571340,
#  1571364,
#  1571511,
#  1571717,
#  1571727,
#  1571732,
#  1571780,
#  1572038,
#  1572049,
#  1572094,
#  1572114,
#  1572156,
#  1572175,
#  1572201,
#  1572220,
#  1572222,
#  1572317,
#  1572352,
#  1572353,
#  1572418,
#  1572433,
#  1572463,
#  1572558,
#  1572685,
#  1572725,
#  1572762,
#  1572768,
#  1572780,
#  1572802,
#  1572851,
#  1572895,
#  1572910,
#  1572948,
#  1572999,
#  1573013,
#  1573064,
#  1573094,
#  1573138,
#  1573149,
#  1573174,
#  1573398,
#  1573478,
#  1573666,
#  1573742,
#  1573836,
#  1573867,
#  1573872,
#  1573876,
#  1573925,
#  1573954,
#  1573967,
#  1574033,
#  1574272,
#  1574306,
#  1574361,
#  1574376,
#  1574521,
#  1574524,
#  1574550,
#  1574646,
#  1574753,
#  1574792,
#  1574944,
#  1575133,
#  1575183,
#  1575203,
#  1575206,
#  1575422,
#  1575424,
#  1575570,
#  1575580,
#  1575672,
#  1575690,
#  1575831,
#  1575851,
#  1575855,
#  1575873,
#  1575886,
#  1575888,
#  1575893,
#  1575919,
#  1575977,
#  1576043,
#  1576071,
#  1576108,
#  1576115,
#  1576117,
#  1576141,
#  1576144,
#  1576249,
#  1576312,
#  1576351,
#  1576420,
#  1576469,
#  1576497,
#  1576508,
#  1576558,
#  1576607,
#  1576623,
#  1576646,
#  1576648,
#  1576662,
#  1576704,
#  1576739,
#  1576744,
#  1576756,
#  1576782,
#  1576789,
#  1576796,
#  1576877,
#  1576970,
#  1577003,
#  1577013,
#  1577039,
#  1577073,
#  1577077,
#  1577143,
#  1577144,
#  1577167,
#  1577202,
#  1577215,
#  1577221,
#  1577265,
#  1577315,
#  1577365,
#  1577769,
#  1577819,
#  1577912,
#  1578131,
#  1701525,
#  1701551,
#  1701553,
#  1701554,
#  1701656,
#  1701672,
#  1701678,
#  1701679,
#  1701692,
#  1701763,
#  1701801,
#  1717095,
#  1717106,
#  1717128,
#  1717242,
#  1717271,
#  1717285,
#  1717316,
#  1717382,
#  1717384,
#  1717435,
#  1717465,
#  1717515,
#  1717528,
#  1717574,
#  1717618,
#  1717672,
#  1717717,
#  1717722,
#  1717783,
#  1717789,
#  1717797,
#  1717867,
#  1717921,
#  1717959,
#  1717988,
#  1717990,
#  1717994,
#  1717999,
#  1718046,
#  1718059,
#  1718071,
#  1718189,
#  1718206,
#  1718222,
#  1718290,
#  1718354,
#  1718360,
#  1718367,
#  1718373,
#  1718397,
#  1718401,
#  1718423,
#  1718456,
#  1718520,
#  1718537,
#  1718550,
#  1718585,
#  1718594,
#  1718665,
#  1718670,
#  1718740,
#  1718743,
#  1718753,
#  1718761,
#  1718828,
#  1718831,
#  1718923,
#  1718943,
#  1718958,
#  1718985,
#  1719026,
#  1719065,
#  1719093,
#  1719124,
#  1719166,
#  1719227,
#  1719262,
#  1719297,
#  1719308,
#  1719358,
#  1719371,
#  1719422,
#  1719472,
#  1719550,
#  1719557,
#  1719667,
#  1719697,
#  1719927,
#  1719974,
#  1720048,
#  1720182,
#  1720196,
#  1720224,
#  1720241,
#  1720425,
#  1720554,
#  1720670,
#  1720673,
#  1720728,
#  1720785,
#  1720794,
#  1720810,
#  1720964,
#  1721071,
#  1721110,
#  1721133,
#  1721150,
#  1721157,
#  1721218,
#  1721231,
#  1721247,
#  1721361,
#  1721409,
#  1721439,
#  1721512,
#  1721523,
#  1721558,
#  1721595,
#  1721614,
#  1721724,
#  1721725,
#  1721787,
#  1721795,
#  1721825,
#  1721879,
#  1721911,
#  1721921,
#  1722134,
#  1722241,
#  1722276,
#  1722289,
#  1722303,
#  1722506,
#  1722549,
#  1722591,
#  1722623,
#  1722627,
#  1722735,
#  1722776,
#  1722816,
#  1722916,
#  1722956,
#  1723047,
#  1723078,
#  1723135,
#  1723146,
#  1723157,
#  1723191,
#  1723338,
#  1723350,
#  1723411,
#  1723449,
#  1723455,
#  1723516,
#  1723529,
#  1723617,
#  1723618,
#  1723624,
#  1723638,
#  1723656,
#  1723671,
#  1723700,
#  1723752,
#  1723843,
#  1723845,
#  1723908,
#  1723918,
#  1723919,
#  1723978,
#  1723993,
#  1724041,
#  1724079,
#  1724096,
#  1724171,
#  1724222,
#  1724227,
#  1724234,
#  1724287,
#  1724304,
#  1724316,
#  1724342,
#  1724355,
#  1724385,
#  1724411,
#  1724498,
#  1724513,
#  1724529,
#  1724615,
#  1724629,
#  1724679,
#  1724719,
#  1724720,
#  1724801,
#  1724806,
#  1724842,
#  1724872,
#  1724879,
#  1724961,
#  1724968,
#  1724975,
#  1725016,
#  1725017,
#  1725018,
#  1725053,
#  1725096,
#  1725133,
#  1725153,
#  1725183,
#  1725190,
#  1725193,
#  1725207,
#  1725310,
#  1725330,
#  1725372,
#  1725376,
#  1725415,
#  1725457,
#  1725470,
#  1725486,
#  1725508,
#  1725533,
#  1725552,
#  1725555,
#  1725558,
#  1725626,
#  1725633,
#  1725688,
#  1725732,
#  1725796,
#  1725815,
#  1725848,
#  1725893,
#  1725907,
#  1725920,
#  1725952,
#  1725953,
#  1725997,
#  1726035,
#  1726045,
#  1726097,
#  1726154,
#  1726211,
#  1726231,
#  1726245,
#  1726291,
#  1726318,
#  1726425,
#  1726636,
#  1726688,
#  1726747,
#  1849064,
#  1849130,
#  1849159,
#  1849195,
#  1849235,
#  1849238,
#  1849249,
#  1849321,
#  1849326,
#  1849334,
#  1849341,
#  1849386,
#  1849398,
#  1849403,
#  1849415,
#  1849430,
#  1849462,
#  1849471,
#  1849474,
#  1849500,
#  1849513,
#  1849547,
#  1849555,
#  1849572,
#  1849581,
#  1849587,
#  1849590,
#  1849610,
#  1849624,
#  1849656,
#  1849664,
#  1849679,
#  1849689,
#  1849698,
#  1849702,
#  1849714,
#  1849734,
#  1849785,
#  1849829,
#  1849846,
#  1849885,
#  1849959,
#  1850007,
#  1850100,
#  1850194,
#  1850285,
#  1863893,
#  1863905,
#  1863909,
#  1863995,
#  1864041,
#  ...]
